# %% [markdown]
# # LetsGrowMore
# ## Name : Pratiksha Nandalal Borse
# ### Data Science Intern
# #### Task-3:Prediction Using Decision Tree Algorithm

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
url="http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

names=['sepal-length','sepal-width','petal-length','petal-width','species']
data=pd.read_csv(url,names=names)
data
# Out:
#      sepal-length  sepal-width  petal-length  petal-width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  150 non-null    float64
#  1   sepal-width   150 non-null    float64
#  2   petal-length  150 non-null    float64
#  3   petal-width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
x= data[['sepal-length','sepal-width','petal-length','petal-width']].values
x[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
Y = data['species']
Y[0:5]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_trainset, x_testset, Y_trainset, Y_testset = train_test_splittrain_x, test_x, trian_y, test_y = train_test_split(x,Y,test_size=0.3, random_state=0)

# %%
SpeciesTree = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)
SpeciesTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
SpeciesTree.fit(x_trainset, Y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# ## Prediction

# %%
predTree = SpeciesTree.predict(x_testset)

# %%
print(predTree[0:5])
print(Y_testset[0:5])
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa']
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# Name: species, dtype: object

# %% [markdown]
# ## Evaluation

# %%
from sklearn import metrics
print("DecisionTree's Accuracy:",metrics.accuracy_score(Y_testset, predTree))
# Out:
# DecisionTree's Accuracy: 0.9777777777777777

# %% [markdown]
# ## Visulization

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
fn = data.columns[1:5]
cn = data["species"].unique().tolist()
SpeciesTree.fit(x,Y)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,10), dpi=300)

tree.plot_tree(SpeciesTree,feature_names=fn,class_names=cn,filled=True);

# %% [markdown]
# ## Predicting species for set of values

# %%
X_new = [[5.4,2.0,1.6,0.5]]

# %%
predTree = SpeciesTree.predict(X_new)

# %%
predTree
# Out:
# array(['Iris-setosa'], dtype=object)
